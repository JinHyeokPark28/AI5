# %%
# 분석
# 점근적 분석(asymtotic analysis)
# 어떤 알고리즘에 큰 입력 데이터셋을 적용할 때, 알고리즘의 제한 동작과 성능을
# 설명하기 위해 사용되는 방법입니다.
# 숫자 1개당 1바이트
# 1Ghz -> 10 ^ 9 : 10억초

# 복잡도
# 복잡도 문제 변환 : 한문제를 원래 문제만큼 어렵게 다른 문제로 변환
# 다항 시간 환산
# 환산 절차가 다항시간을 걸리는 것을 의미

# 복잡도 P
# 결정론적 튜링 기계로 다항시간안에 풀수 있는 판정 문제를 모아둔 복잡도 종류
# 계산의 각 단계에서 단 한가자의 가능성만 고려할 수 있는 알고리즘이다.
# 다항시간안에 풀수있다.


# 복잡도 NP
# 비결정론적 튜링 기계로 다항시간안에 풀수 있는 판정 문제의 집합입니다.
# P와 구분되는 것은 비결정론적 이라는 점이다.
# 각 단계에서 여러 가능성을 동시에 고려할수있는 알고리즘을 통해서
# 다항시간안에 문제를 풀수있는것을 뜻합니다.
# NP에 속하는 어떤 문제만큼 어렵다면 이를 NP 난해라고 합니다.
# 만일 모든 NP문제가 다항 시간에 어떤 문제로 환산할 수 있다면 NP난해문지이지만
# NP 난해 문제는 NP 난해문제가 아닐수도 있습니다.
# 더 어려울수도 있습니다.
# NP문제이자 NP 난해 문제를 NP 완전 이라고 부릅니다.

# 재귀알고리즘
# 1) 재귀 알고리즘 베이스 케이스(재귀 호출을 하지 않는 종료 시나리오)가 필요
# 2) 재귀 알고리즘의 상태를 변경하고 베이스 케이스로 이동합니다.
# 3) 재귀 알고리즘은 재귀적으로 자신을 호출한다.
# 재귀 호출에 대해 재귀 함수는 인수, 반환 주소, 지역변수를 메모리의 스택 할당
# 스택에 넣고 꺼내는데 시간을 소비
# n의 개수 -> 재귀의 깊이
# O(n)
# 재귀는 비용이 비쌉니다. 
# 가끔 오버플로우를 일으킬수있다.
# 반복문을 사용하는게 더 좋을 수 있다.
